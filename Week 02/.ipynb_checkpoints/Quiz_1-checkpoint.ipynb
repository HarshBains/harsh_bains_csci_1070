# %% [markdown]
# # Question 1: Image of CSCI Directory ![Screenshot 2024-08-29 at 6.30.58 PM.png](attachment:ff5f452a-d6a2-4de4-9815-84eab7998316.png)

# %%
# Question 2: Explain why your tree structure is what it is.

# In the second line above the terminal response to the "tree" command, you can see that I have saved my repository to my Mac user profile; 
# following that, I am intending to create a subfolder representing the work completed each week, as well as a subfolder representing the
# class repo (that being csci_1070). Every file saved in a folder ending in .ipynb is a Jupyter Notebook file, which I can predict will 
# likely be many by the end of the course :)

# %%
# Question 3: Write a Python expression to iterate over the following dictionary:
# months = ["January","February","March","April","May","June","July","August","September","October","November","December"]. 
# Have conditional logic to print "my birthday" if the month printed is your birth month. 

months = ["January","February","March","April","May","June","July","August","September","October","November","December"]

for month in months:
    
    if (month != "May"):
        print(month)
    else:
        print(month + " (My birthday is on the 2nd!)")
# Out:
# January
# February
# March
# April
# May (My birthday is on the 2nd!)
# June
# July
# August
# September
# October
# November
# December
