# %% [markdown]
# # Scope (LEGB Rule)
#
# Local - only available to other code in this scope. A function, for example, only has access to the names defined in that function or passed into it via arguments.
#
# Enclosing - only exists for nested functions. Inner nests can have access to the names in outer nests.
#
# Global - available to all your code and can pass through modules, classes, etc.
#
# Built-in - all names that are created by Python when you run a script
#
# What does being aware of your scope help do and avoid?
#
# Avoids name collision
#
# Encapsulates functions
#
#
#
# Python Constructor
#
# __ (double underscore) - "dunder"
#
# __init__

# %% [markdown]
# # Constructors
#
# Constructors get created when you create an instance of a class.
#
# __init__(__ is "dunder")

# %%
class a_sample_class:

    # default/basic constructor
    def __init__(self, one, two):
        self.first = one
        self.second = two
    
    # an instance method for printing
    def print_vars(self):
        print(self.var)
    
#create instance of class
obj = a_sample_class(2, 8)
    
#call instance method to get value for var
obj.print_vars()

globals()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 16
#      13 obj = a_sample_class(2, 8)
#      15 #call instance method to get value for var
# ---> 16 obj.print_vars()
#      18 globals()
#
# Cell In[22], line 10, in a_sample_class.print_vars(self)
#       9 def print_vars(self):
# ---> 10     print(self.var)
#
# AttributeError: 'a_sample_class' object has no attribute 'var'

# %%
class a_sample_class:
    class_attr = 5

    def __init__(self, one, two):
        #instance attribute
        self.first = one
        self.first = two

#object is instance of class
obj = a_sample_class(17,42)

#instance attribute as property of object
print(obj.first)

#class attribute as property of object
print(obj.class_attr)

#instance attribute as property of class
#print(a_sample_class.first)

#class attribute as property of class
print(a_sample_class.class_attr)

help(obj)

# returns the current module namespace
# namespace = mapping between objects and current names. These are defined names, and they also include information about the objects each
# name references.
globals()
# Out:
# 42
# 5
# 5
# Help on a_sample_class in module __main__ object:
#
# class a_sample_class(builtins.object)
#  |  a_sample_class(one, two)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, one, two)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  class_attr = 5
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# default/basic constructor',
#   '# default/basic constructor\ndef __init__(self):\n    self.var = 0\n\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sample_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n# default/basic constructor\ndef __init__(self):\n    self.var = 0\n\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sample_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n    #call instance method to get value for var\n    obj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n#call instance method to get value for var\n obj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class()\n    \n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars(first)',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars(one)',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   "# Classes\n\nThree types: class methods, static methods, and instance methods\nNeed to create an object to call non-static methods\n\nClass method: CAN modify class state, CAN'T modify object state",
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()\n\nglobals()',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()'],
#  '_oh': {23: {...}},
#  '_dh': [PosixPath('/Users/harshbains/harsh_bains_csci_1070/Week 03')],
#  'In': ['',
#   '# default/basic constructor',
#   '# default/basic constructor\ndef __init__(self):\n    self.var = 0\n\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sample_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n# default/basic constructor\ndef __init__(self):\n    self.var = 0\n\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sample_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n    #call instance method to get value for var\n    obj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n#call instance method to get value for var\n obj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class()\n    \n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars(first)',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars(one)',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#   "# Classes\n\nThree types: class methods, static methods, and instance methods\nNeed to create an object to call non-static methods\n\nClass method: CAN modify class state, CAN'T modify object state",
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)',
#   'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()\n\nglobals()',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()',
#   'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()'],
#  'Out': {23: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x106d4ffe0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x106d68530>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x106d68530>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': '',
#  '___': '',
#  '__session__': '/Users/harshbains/harsh_bains_csci_1070/Week 03/Untitled.ipynb',
#  '_i': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()',
#  '_ii': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()\n\nglobals()',
#  '_iii': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)',
#  '_i1': '# default/basic constructor',
#  '_i2': '# default/basic constructor\ndef __init__(self):\n    self.var = 0\n\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sample_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#  '__init__': <function __main__.__init__(self)>,
#  'print_vars': <function __main__.print_vars(self)>,
#  '_i3': 'class a_sample_class:\n\n# default/basic constructor\ndef __init__(self):\n    self.var = 0\n\n# an instance method for printing\ndef print_vars(self):\n    print(self.var)\n\n#create instance of class\nobj = a_sample_class()\n\n#call instance method to get value for var\nobj.print_vars()',
#  '_i4': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n    #call instance method to get value for var\n    obj.print_vars()',
#  '_i5': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n#call instance method to get value for var\n obj.print_vars()',
#  '_i7': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n    #create instance of class\n    obj = a_sample_class()\n    \n#call instance method to get value for var\nobj.print_vars()',
#  '_i8': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self):\n        self.var = 0\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class()\n    \n#call instance method to get value for var\nobj.print_vars()',
#  'a_sample_class': __main__.a_sample_class,
#  'obj': <__main__.a_sample_class at 0x10881b620>,
#  '_i9': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars(first)',
#  '_i10': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars(one)',
#  '_i11': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()',
#  '_i12': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)',
#  '_i13': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)',
#  '_i14': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)',
#  '_i15': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)',
#  '_i16': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#  '_i17': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#  '_i18': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#  '_i19': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\nprint(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)',
#  '_i20': "# Classes\n\nThree types: class methods, static methods, and instance methods\nNeed to create an object to call non-static methods\n\nClass method: CAN modify class state, CAN'T modify object state",
#  '_i21': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)',
#  '_i22': 'class a_sample_class:\n\n    # default/basic constructor\n    def __init__(self, one, two):\n        self.first = one\n        self.second = two\n    \n    # an instance method for printing\n    def print_vars(self):\n        print(self.var)\n    \n#create instance of class\nobj = a_sample_class(2, 8)\n    \n#call instance method to get value for var\nobj.print_vars()\n\nglobals()',
#  '_i23': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()',
#  '_23': {...},
#  '_i24': 'class a_sample_class:\n    class_attr = 5\n\n    def __init__(self, one, two):\n        #instance attribute\n        self.first = one\n        self.first = two\n\n#object is instance of class\nobj = a_sample_class(17,42)\n\n#instance attribute as property of object\nprint(obj.first)\n\n#class attribute as property of object\nprint(obj.class_attr)\n\n#instance attribute as property of class\n#print(a_sample_class.first)\n\n#class attribute as property of class\nprint(a_sample_class.class_attr)\n\nhelp(obj)\n\nglobals()'}

# %% [markdown]
# # Classes
#
# Three types: class methods, static methods, and instance methods
# Need to create an object to call non-static methods
#
# Class method: CAN modify class state, CAN'T modify object state, used for factory functions
# Static method:

# %%
#Instance, class, and static Methods
